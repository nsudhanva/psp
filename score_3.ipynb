# %%
import numpy as np
import pandas as pd
import math
import re
from scipy.stats import skew, kurtosis

# %%
df = pd.read_csv('data_3.csv', index_col='id')

# %%
df.head()
# Out:
#      fragment_one  start_one  end_one  resolution_one chain_id_one  \
# id
# 2661    METASNILE          1        3            2.80            A
# 2672    METASNILE          1        3            2.80            A
# 2679    METASNILE        716      718            1.66            A
# 2911    ASNILEPHE          2        4            2.80            A
# 2936    ASNILEPHE          2        4            2.80            A
#
#      protein_id_one fragment_two  start_two  end_two  resolution_two  \
# id
# 2661       104L.pdb    METASNILE        716      718            1.66
# 2672       104L.pdb    METASNILE          5        7            2.71
# 2679       4Y04.pdb    METASNILE          5        7            2.71
# 2911       104L.pdb    ASNILEPHE         71       73            2.20
# 2936       104L.pdb    ASNILEPHE        303      305            1.67
#
#      chain_id_two protein_id_two      rms  fragment_type  seq_type     tscore
# id
# 2661            A       4Y04.pdb  2.35063            111         3   1.638366
# 2672            A       4Y4M.pdb  1.54444            111         3  -1.812570
# 2679            A       4Y4M.pdb  2.00858            111         3   0.174204
# 2911            A       4Y3K.pdb  2.17766            111         3  63.868294
# 2936            A       4Y4X.pdb  2.56818            111         3  81.222265

# %%
def calc_t_score(group):
    mean = group['rms'].mean()    
    std = group['rms'].std()
    count = group['rms'].count()
    group['n'] = count
    group['mean'] = mean
    group['std'] = std
#     print(mean, std, count)
#     print(group['rms'])
#     print(group['fragment_one'].unique())

    if count <= 30:
        group['tscore'] = (group['rms'] - mean) / (std/(math.sqrt(count)))
    else:
        group['tscore'] = (group['rms'] - mean) / std
        
    group['skew'] = skew(group['tscore'])
    group['kurtosis'] = kurtosis(group['tscore'], fisher=True)
    return group

df = df.groupby('fragment_one').apply(calc_t_score)

# %%
df_final = df.drop(columns=['start_one', 'end_one', 'resolution_one',
       'chain_id_one', 'protein_id_one', 'fragment_two', 'start_two',
       'end_two', 'resolution_two', 'chain_id_two', 'protein_id_two',
       'seq_type'])

# %%
df_final.head(50)
# Out:
#      fragment_one       rms  fragment_type    tscore    n      mean       std  \
# id
# 2661    METASNILE  2.350630            111  1.638366    3  1.967883  0.404633
# 2672    METASNILE  1.544440            111 -1.812570    3  1.967883  0.404633
# 2679    METASNILE  2.008580            111  0.174204    3  1.967883  0.404633
# 2911    ASNILEPHE  2.177660            111  2.398624  709  0.740419  0.599194
# 2936    ASNILEPHE  2.568180            111  3.050366  709  0.740419  0.599194
# 3027    ASNILEPHE  2.563590            111  3.042706  709  0.740419  0.599194
# 3318    ASNILEPHE  1.280320            111  0.901046  709  0.740419  0.599194
# 3329    ASNILEPHE  1.278850            111  0.898593  709  0.740419  0.599194
# 3334    ASNILEPHE  0.061513            111 -1.133031  709  0.740419  0.599194
# 3343    ASNILEPHE  1.413760            111  1.123745  709  0.740419  0.599194
# 3355    ASNILEPHE  1.278770            111  0.898459  709  0.740419  0.599194
# 3365    ASNILEPHE  0.057753            111 -1.139306  709  0.740419  0.599194
# 3377    ASNILEPHE  0.059533            111 -1.136335  709  0.740419  0.599194
# 3384    ASNILEPHE  1.278660            111  0.898276  709  0.740419  0.599194
# 3355 -0.016801 -1.630972
# 3365 -0.016801 -1.630972
# 3377 -0.016801 -1.630972
# 3384 -0.016801 -1.630972
# 3406 -0.016801 -1.630972
# 3418 -0.016801 -1.630972
# 3456 -0.016801 -1.630972
# 3467 -0.016801 -1.630972
# 3473 -0.016801 -1.630972
# 3488 -0.016801 -1.630972
# 3496 -0.016801 -1.630972
# 3513 -0.016801 -1.630972
# 3520 -0.016801 -1.630972
# 3525 -0.016801 -1.630972
# 3528 -0.016801 -1.630972
# 3533 -0.016801 -1.630972
# 3541 -0.016801 -1.630972
# 3552 -0.016801 -1.630972
# 3562 -0.016801 -1.630972
# 3570 -0.016801 -1.630972
# 3580 -0.016801 -1.630972
# 3587 -0.016801 -1.630972
# 3599 -0.016801 -1.630972
# 3616 -0.016801 -1.630972
# 3626 -0.016801 -1.630972
# 3640 -0.016801 -1.630972
# 3649 -0.016801 -1.630972
# 3659 -0.016801 -1.630972
# 3673 -0.016801 -1.630972
# 3687 -0.016801 -1.630972
# 3700 -0.016801 -1.630972
# 3710 -0.016801 -1.630972
# 3723 -0.016801 -1.630972
# 3741 -0.016801 -1.630972
# 3753 -0.016801 -1.630972
# 3769 -0.016801 -1.630972
# 3779 -0.016801 -1.630972
# 3799 -0.016801 -1.630972
# 3808 -0.016801 -1.630972
# 3822 -0.016801 -1.630972

# %%
df_final_clean = df_final.groupby(['fragment_one']).mean()[['fragment_type', 'n', 'mean', 'std', 'skew', 'kurtosis']]

# %%
df_final_clean = df_final_clean.reset_index().fillna(0)

# %%
df_final_clean.head()
# Out:
#   fragment_one  fragment_type    n      mean       std      skew  kurtosis
# 0    ALAALAALA              3  325  0.864336  0.729351  0.402740 -1.599657
# 1    ALAALAARG             21   91  1.488131  0.497887 -0.580775  0.135429
# 2    ALAALAASN             21   21  0.661898  0.287421 -0.326125 -1.022283
# 3    ALAALAASP             21  120  1.274343  0.858643  0.112329 -1.472973
# 4    ALAALAGLN             21    6  0.845359  0.362645 -0.875807 -0.479346

# %%
seq = {
    'ALA': 'A',
    'ARG': 'R',
    'ASN' : 'N',
    'ASP': 'D',
    'CYS': 'C',
    'GLU': 'E',
    'GLN': 'Q',
    'GLY' : 'G',
    'HIS': 'H',
    'ILE': 'I',
    'LEU': 'L',
    'LYS': 'K',
    'MET': 'M',
    'PHE': 'F',
    'PRO': 'P',
    'SER': 'S',
    'THR': 'T',
    'TRP': 'W',
    'TYR': 'Y',
    'VAL': 'V'
}

# %%
def find_replace_multi_ordered(string):
    
    for item in sorted(seq.keys(), key = len, reverse = True):
        string = re.sub(item, seq[item], string)
    return string

# %%
df_final_clean['fragment_one'] = df_final_clean['fragment_one'].apply(find_replace_multi_ordered)

# %%
df_final_clean.head()
# Out:
#   fragment_one  fragment_type    n      mean       std      skew  kurtosis
# 0          AAA              3  325  0.864336  0.729351  0.402740 -1.599657
# 1          AAR             21   91  1.488131  0.497887 -0.580775  0.135429
# 2          AAN             21   21  0.661898  0.287421 -0.326125 -1.022283
# 3          AAD             21  120  1.274343  0.858643  0.112329 -1.472973
# 4          AAQ             21    6  0.845359  0.362645 -0.875807 -0.479346
